# %% [markdown]
# ## Data Set Train and Test Distribution
#
# > the main idea here is to check the dataset distribution of train and test split.

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
